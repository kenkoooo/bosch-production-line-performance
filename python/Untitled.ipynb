# %%
import pandas as pd

# %%
df = pd.read_hdf("../hdf/train_S24_C_md5.hdf")

# %%
md5_sum = df["S24_C_md5"].value_counts().index[0]

# %%
df[df["S24_C_md5"]==md5_sum]
# Out:
#               S24_C_md5
# Id
# 4.0        1.751497e+38
# 6.0        1.751497e+38
# 7.0        1.751497e+38
# 9.0        1.751497e+38
# 11.0       1.751497e+38
# 13.0       1.751497e+38
# 14.0       1.751497e+38
# 18.0       1.751497e+38
# 23.0       1.751497e+38
# 26.0       1.751497e+38
# 27.0       1.751497e+38
# 28.0       1.751497e+38
# 31.0       1.751497e+38
# 34.0       1.751497e+38
# 38.0       1.751497e+38
# 41.0       1.751497e+38
# 44.0       1.751497e+38
# 47.0       1.751497e+38
# 49.0       1.751497e+38
# 52.0       1.751497e+38
# 55.0       1.751497e+38
# 56.0       1.751497e+38
# 57.0       1.751497e+38
# 63.0       1.751497e+38
# 68.0       1.751497e+38
# 70.0       1.751497e+38
# 71.0       1.751497e+38
# 72.0       1.751497e+38
# 73.0       1.751497e+38
# 75.0       1.751497e+38
# ...                 ...
# 2367421.0  1.751497e+38
# 2367423.0  1.751497e+38
# 2367429.0  1.751497e+38
# 2367430.0  1.751497e+38
# 2367431.0  1.751497e+38
# 2367433.0  1.751497e+38
# ...
