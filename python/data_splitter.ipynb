# %%
import pandas as pd
import numpy as np

# %%
# categorical
X=pd.read_csv("../output/reduced_merged.csv.gz",
              compression="gzip",
              index_col=0,
              usecols=list(range(248)))

# %%
# date
X=pd.read_csv("../output/reduced_merged.csv.gz",
              compression="gzip",
              index_col=0,
              usecols=np.concatenate([[0], list(range(248,409))])
             )

# %%
# numeric
X=pd.read_csv("../output/reduced_merged.csv.gz",
              compression="gzip",
              index_col=0,
              usecols=np.concatenate([[0], list(range(409,1378))])
             )

# %%
X.to_csv("../output/reduced_train_numeric.csv.gz", compression="gzip")
X=pd.read_csv("../output/reduced_train_numeric.csv.gz", compression="gzip", index_col=0)
X
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a16e146da8b4> in <module>()
# ----> 1 X.to_csv("../output/reduced_train_numeric.csv.gz", compression="gzip")
#       2 X=pd.read_csv("../output/reduced_train_numeric.csv.gz", compression="gzip", index_col=0)
#       3 X
#
# /Users/um003282/.pyenv/versions/3.5.2/lib/python3.5/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal, **kwds)
#    1342                                      doublequote=doublequote,
#    1343                                      escapechar=escapechar, decimal=decimal)
# -> 1344         formatter.save()
#    1345
#    1346         if path_or_buf is None:
#
# ...

# %%
for c in X:
    break
columns=c.columns
len(columns)

# %%
# Out:
# Index(['L0_S0_F0', 'L0_S0_F2', 'L0_S0_F4', 'L0_S0_F6', 'L0_S0_F8', 'L0_S0_F10',
#        'L0_S0_F12', 'L0_S0_F14', 'L0_S0_F16', 'L0_S0_F18',
#        ...
#        'L3_S50_F4245', 'L3_S50_F4247', 'L3_S50_F4249', 'L3_S50_F4251',
#        'L3_S50_F4253', 'L3_S51_F4256', 'L3_S51_F4258', 'L3_S51_F4260',
#        'L3_S51_F4262', 'Response'],
#       dtype='object', length=969)

# %%
for column in columns:
    print(column)
# Out:
# L0_S1_F25
# L0_S1_F27
# L0_S1_F29
# L0_S1_F31
# L0_S2_F33
# L0_S2_F35
# L0_S4_F105
# L0_S4_F107
# L0_S4_F108
# L0_S4_F110
# L0_S4_F112
# L0_S4_F113
# L0_S6_F119
# L0_S6_F121
# L0_S9_F151
# L0_S9_F153
# L0_S9_F154
# L0_S9_F156
# L0_S9_F158
# L0_S9_F159
# L0_S9_F164
# L0_S9_F166
# L0_S9_F169
# L0_S9_F176
# L0_S9_F178
# L0_S9_F179
# L0_S10_F215
# L0_S10_F217
# L0_S10_F218
# L0_S10_F220
# L0_S10_F222
# L0_S10_F223
# L0_S10_F230
# L0_S10_F233
# L0_S10_F240
# L0_S10_F242
# L0_S10_F243
# L0_S11_F279
# L0_S11_F281
# L0_S14_F359
# L0_S14_F361
# L0_S15_F396
# L0_S16_F422
# L0_S16_F424
# L0_S16_F425
# L0_S21_F468
# L0_S21_F470
# L0_S21_F471
# L0_S21_F473
# L0_S21_F475
# L0_S21_F476
# L0_S21_F483
# L0_S21_F486
# L0_S21_F493
# L0_S21_F495
# L0_S21_F496
# L0_S22_F542
# L0_S22_F544
# L0_S22_F545
# L0_S22_F547
# L0_S22_F549
# L0_S22_F550
# L0_S22_F555
# L0_S22_F557
# L0_S22_F560
# L0_S22_F567
# L0_S22_F569
# L0_S22_F570
# L1_S24_F675
# L1_S24_F695
# L1_S24_F696
# L1_S24_F698
# L1_S24_F699
# ...
